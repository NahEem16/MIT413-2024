# %% [markdown]
# # Question 1 - Linear Regression

# %% [markdown]
# **Dataset Description**
#
# Below is a list containing the year of experience and salary of a worker.
#
# `YearsExperience`
#
# `Salary`

# %% [markdown]
# The goal of this assignment is to build and train a linear regression model to
#
# predict the **salary** based on the **year of experience**.

# %%
yearsExperience = [1.2, 1.4, 1.6, 2.1, 2.3, 3, 3.1, 3.3, 3.3, 3.8, 4, 4.1, 4.1,
                   4.2, 4.6, 5, 5.2, 5.4, 6, 6.1, 6.9, 7.2, 8, 8.3, 8.8, 9.1,
                   9.6, 9.7, 10.4, 10.6]

salary = [39344, 46206, 37732, 43526, 39892, 56643, 60151, 54446, 64446, 57190,
          63219, 55795, 56958, 57082, 61112, 67939, 66030, 83089, 81364, 93941,
          91739, 98274, 101303, 113813, 109432, 105583, 116970, 112636, 122392,
          121873]

# %% [markdown]
# You are required to use the above datasets: `yearsExperience` and `salary`
# Kindly run the above cell to initialize the two variables:

# %% [markdown]
# Import the necessary libraries

# %%
###### Put your code here

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np

print("Libraries installed successfully")
# Out:
# Libraries installed successfully

# %% [markdown]
# Convert the your data to appropriate `type` so it can be used in the training model

# %%
####### Put your code here
#defining Years of Experiance of the car
Years_Exp = [1.2, 1.4, 1.6, 2.1, 2.3, 3, 3.1, 3.3, 3.3, 3.8, 4, 4.1, 4.1,
                   4.2, 4.6, 5, 5.2, 5.4, 6, 6.1, 6.9, 7.2, 8, 8.3, 8.8, 9.1,
                   9.6, 9.7, 10.4, 10.6]
Years_ExpNP = np.array(Years_Exp, dtype = np.float32)
Years_ExpNP = Years_ExpNP.reshape(-1, 1)

#converting the numpy array to tensor
Years_ExpT0 = Variable(torch.from_numpy(Years_ExpNP))
print(Years_ExpT0)

#definig Salary
Salary = [39344, 46206, 37732, 43526, 39892, 56643, 60151, 54446, 64446, 57190,
          63219, 55795, 56958, 57082, 61112, 67939, 66030, 83089, 81364, 93941,
          91739, 98274, 101303, 113813, 109432, 105583, 116970, 112636, 122392,
          121873]
SalaryNP = np.array(Salary, dtype = np.float32)
SalaryNP = SalaryNP.reshape(-1, 1)

#converting the numpy array to tensor
SalaryT0 = Variable(torch.from_numpy(SalaryNP))
print(SalaryT0)
# Out:
# tensor([[ 1.2000],
#         [ 1.4000],
#         [ 1.6000],
#         [ 2.1000],
#         [ 2.3000],
#         [ 3.0000],
#         [ 3.1000],
#         [ 3.3000],
#         [ 3.3000],
#         [ 3.8000],
#         [ 4.0000],
#         [ 4.1000],
#         [ 4.1000],
#         [ 4.2000],
#         [ 4.6000],
#         [ 5.0000],
#         [ 5.2000],
#         [ 5.4000],
#         [ 6.0000],
#         [ 6.1000],
#         [ 6.9000],
#         [ 7.2000],
#         [ 8.0000],
#         [ 8.3000],
#         [ 8.8000],
#         [ 9.1000],
#         [ 9.6000],
#         [ 9.7000],
#         [10.4000],
#         [10.6000]])
# tensor([[ 39344.],
#         [ 46206.],
#         [ 37732.],
#         [ 43526.],
#         [ 39892.],
#         [ 56643.],
#         [ 60151.],
#         [ 54446.],
#         [ 64446.],
#         [ 57190.],
#         [ 63219.],
#         [ 55795.],
#         [ 56958.],
#         [ 57082.],
#         [ 61112.],
#         [ 67939.],
#         [ 66030.],
#         [ 83089.],
#         [ 81364.],
#         [ 93941.],
#         [ 91739.],
#         [ 98274.],
#         [101303.],
#         [113813.],
#         [109432.],
#         [105583.],
#         [116970.],
#         [112636.],
#         [122392.],
#         [121873.]])

# %% [markdown]
# Visualize your data by ploting two variables `yearExperience` vs `salary`
#
# Your graph should have the tile: `Year of Experience vs Salary`
#
# Both the x- and y-axis should be labeled appropriately

# %%
####### Put your code here

plt.scatter(Years_Exp, Salary)
plt.xlabel("Years of Experience Y")
plt.ylabel("Salary $")
plt.title("Years of Experience Y VS Salary $")
plt.show()

# %% [markdown]
# *  Create a class `LinearRegression` which inherit from the `nn` (neural network) class.
# *  Make sure the linear function and forward function are defined appropriately in the `LinearRegression`.
# *  Again define the number of input and output dimension for your data
# * Define the loss function using `MSELoss()` function
# *  Define your own learning rate (`lr =  `)
# * User `SDG` optimizer for your model
# * Train your model by setting the `iteration_number` to 100001

# %%
######### Put your code here

class LinearRegression(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearRegression, self).__init__()
        
        #Linear function
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        return self.linear(x)
#defining model
input_dim = 1
output_dim = 1
model = LinearRegression(input_dim, output_dim)

#loss function
mse = nn.MSELoss()

#Optim Parameters
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001)

# %% [markdown]
# Plot your loss function by labeling the axis appropriately
# and setting an appropriate title for the graph

# %%
####### Put your code here
loss_list=[]
iterations = 100001
for i in range(iterations):
    optimizer.zero_grad()
    
    results = model(Years_ExpT0)
    
    loss = mse(results, SalaryT0)
    
    loss.backward()
    
    optimizer.step()
    
    loss_list.append(loss.data)
    
    if (i % 50 == 0):
        print('epoch {}, loss{}'.format(i, loss.data))
# Out:
# epoch 0, loss5575605248.0
# epoch 50, loss139516400.0
# epoch 100, loss133183520.0
# epoch 150, loss129078240.0
# epoch 200, loss125139048.0
# epoch 250, loss121358536.0
# epoch 300, loss117730208.0
# epoch 350, loss114248072.0
# epoch 400, loss110906192.0
# epoch 450, loss107698840.0
# epoch 500, loss104620712.0
# epoch 550, loss101666520.0
# epoch 600, loss98831336.0
# epoch 650, loss96110344.0
# epoch 700, loss93498920.0
# epoch 750, loss90992672.0
# epoch 800, loss88587384.0
# epoch 850, loss86278944.0
# epoch 900, loss84063512.0
# epoch 950, loss81937280.0
# epoch 1000, loss79896696.0
# epoch 1050, loss77938280.0
# epoch 1100, loss76058744.0
# epoch 1150, loss74254872.0
# epoch 1200, loss72523704.0
# epoch 1250, loss70862248.0
# epoch 1300, loss69267704.0
# epoch 1350, loss67737368.0
# epoch 1400, loss66268664.0
# epoch 1450, loss64859144.0
# epoch 1500, loss63506384.0
# epoch 1550, loss62208092.0
# epoch 1600, loss60962104.0
# epoch 1650, loss59766280.0
# epoch 1700, loss58618684.0
# epoch 1750, loss57517232.0
# epoch 1800, loss56460164.0
# epoch 1850, loss55445668.0
# epoch 1900, loss54472024.0
# epoch 1950, loss53537608.0
# epoch 2000, loss52640812.0
# epoch 2050, loss51780140.0
# epoch 2100, loss50954124.0
# epoch 2150, loss50161360.0
# epoch 2200, loss49400564.0
# epoch 2250, loss48670380.0
# epoch 2300, loss47969620.0
# epoch 2350, loss47297084.0
# epoch 2400, loss46651624.0
# epoch 2450, loss46032176.0
# epoch 2500, loss45437652.0
# epoch 2550, loss44867076.0
# epoch 2600, loss44319496.0
# epoch 2650, loss43793972.0
# epoch 2700, loss43289608.0
# epoch 2750, loss42805564.0
# epoch 2800, loss42341000.0
# epoch 2850, loss41895172.0
# epoch 2900, loss41467276.0
# epoch 2950, loss41056604.0
# epoch 3000, loss40662484.0
# epoch 3050, loss40284240.0
# epoch 3100, loss39921224.0
# epoch 3150, loss39572844.0
# epoch 3200, loss39238480.0
# epoch 3250, loss38917588.0
# epoch 3300, loss38609620.0
# epoch 3350, loss38314060.0
# epoch 3400, loss38030420.0
# epoch 3450, loss37758180.0
# epoch 3500, loss37496904.0
# epoch 3550, loss37246152.0
# epoch 3600, loss37005500.0
# epoch 3650, loss36774552.0
# epoch 3700, loss36552876.0
# epoch 3750, loss36340176.0
# epoch 3800, loss36135996.0
# epoch 3850, loss35940048.0
# epoch 3900, loss35752016.0
# epoch 3950, loss35571528.0
# epoch 4000, loss35398332.0
# epoch 4050, loss35232112.0
# epoch 4100, loss35072584.0
# epoch 4150, loss34919472.0
# epoch 4200, loss34772520.0
# epoch 4250, loss34631500.0
# epoch 4300, loss34496148.0
# epoch 4350, loss34366264.0
# epoch 4400, loss34241596.0
# epoch 4450, loss34121968.0
# epoch 4500, loss34007140.0
# epoch 4550, loss33896936.0
# epoch 4600, loss33791180.0
# epoch 4650, loss33689672.0
# epoch 4700, loss33592260.0
# epoch 4750, loss33498764.0
# epoch 4800, loss33409042.0
# epoch 4850, loss33322934.0
# epoch 4900, loss33240280.0
# epoch 4950, loss33160978.0
# epoch 5000, loss33084842.0
# epoch 5050, loss33011796.0
# epoch 5100, loss32941686.0
# epoch 5150, loss32874398.0
# epoch 5200, loss32809822.0
# epoch 5250, loss32747842.0
# epoch 5300, loss32688364.0
# epoch 5350, loss32631272.0
# epoch 5400, loss32576484.0
# epoch 5450, loss32523906.0
# epoch 5500, loss32473446.0
# epoch 5550, loss32425010.0
# epoch 5600, loss32378534.0
# epoch 5650, loss32333922.0
# epoch 5700, loss32291116.0
# epoch 5750, loss32250028.0
# epoch 5800, loss32210604.0
# epoch 5850, loss32172748.0
# epoch 5900, loss32136434.0
# epoch 5950, loss32101574.0
# epoch 6000, loss32068130.0
# epoch 6050, loss32036008.0
# epoch 6100, loss32005206.0
# epoch 6150, loss31975624.0
# epoch 6200, loss31947250.0
# epoch 6250, loss31920020.0
# epoch 6300, loss31893876.0
# epoch 6350, loss31868778.0
# epoch 6400, loss31844708.0
# epoch 6450, loss31821602.0
# epoch 6500, loss31799426.0
# epoch 6550, loss31778140.0
# epoch 6600, loss31757716.0
# epoch 97500, loss31270950.0
# epoch 97550, loss31270950.0
# epoch 97600, loss31270950.0
# epoch 97650, loss31270950.0
# epoch 97700, loss31270950.0
# epoch 97750, loss31270950.0
# epoch 97800, loss31270950.0
# epoch 97850, loss31270950.0
# epoch 97900, loss31270950.0
# epoch 97950, loss31270950.0
# epoch 98000, loss31270950.0
# epoch 98050, loss31270950.0
# epoch 98100, loss31270950.0
# epoch 98150, loss31270950.0
# epoch 98200, loss31270950.0
# epoch 98250, loss31270950.0
# epoch 98300, loss31270950.0
# epoch 98350, loss31270950.0
# epoch 98400, loss31270950.0
# epoch 98450, loss31270950.0
# epoch 98500, loss31270950.0
# epoch 98550, loss31270950.0
# epoch 98600, loss31270950.0
# epoch 98650, loss31270950.0
# epoch 98700, loss31270950.0
# epoch 98750, loss31270950.0
# epoch 98800, loss31270950.0
# epoch 98850, loss31270950.0
# epoch 98900, loss31270950.0
# epoch 98950, loss31270950.0
# epoch 99000, loss31270950.0
# epoch 99050, loss31270950.0
# epoch 99100, loss31270950.0
# epoch 99150, loss31270950.0
# epoch 99200, loss31270950.0
# epoch 99250, loss31270950.0
# epoch 99300, loss31270950.0
# epoch 99350, loss31270950.0
# epoch 99400, loss31270950.0
# epoch 99450, loss31270950.0
# epoch 99500, loss31270950.0
# epoch 99550, loss31270950.0
# epoch 99600, loss31270950.0
# epoch 99650, loss31270950.0
# epoch 99700, loss31270950.0
# epoch 99750, loss31270950.0
# epoch 99800, loss31270950.0
# epoch 99850, loss31270950.0
# epoch 99900, loss31270950.0
# epoch 99950, loss31270950.0
# epoch 100000, loss31270950.0

# %%
#plotting Loss Function
plt.plot(range(iterations),loss_list)
plt.title('Loss Function')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Question 2 - Classification

# %% [markdown]
# #**Objective:**
# This assignment aims to develop a deep learning model using PyTorch to classify
#
# Pneumonia based on X-ray images. You will train and evaluate the model, and visualize its performance.
#
# ### **Data:**
# You are provided with a dataset containing X-ray images labeled as either "NORMAL" or "PNEUMONIA" on Canvas.
#
# ## **Tasks:**
#
# ### **Import libraries and load data:**
# Import necessary libraries like PyTorch, torchvision, and other relevant libraries.
#
# Load the provided dataset using appropriate data loaders from torchvision.
# Preprocess the data as needed (e.g., resize, normalize, data augmentation).
#
# ### **Define the model:**
# Design a convolutional neural network (CNN) model using PyTorch modules.
#
# Consider including convolutional layers, pooling layers, activation functions
#
# (e.g., ReLU), and a final fully connected layer with two units (fracture or
#
# normal).
#
# ### **Compile the model:**
# Specify an appropriate optimizer (e.g., Adam) and loss function (e.g., binary
#
# cross-entropy) for binary classification.
#
# Define metrics to track performance during training (e.g., accuracy).
#
# ###**Train the model:**
# Train the model on the training set for a specified number of epochs.
#
# ###**Evaluate the model:**
# Visualize the model's predictions on some test images.
#
# Plot a graph(s) to show the accuracy and loss of the model on the test sets.

# %%
###Code goes here. Create as many cells you want to complete your task
#Importing Libraries

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.utils.data import DataLoader

print("import successful!!")
# Out:
# import successful!!

# %%
# Define data transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to 224x224
    transforms.ToTensor(),  # Convert images to PyTorch tensors
    transforms.Normalize((0.5,), (0.5,))  # Normalize images
])

# Define train and test datasets with double backslashes
train_dataset = torchvision.datasets.ImageFolder(root="C:\\Users\\user\\Desktop\\xray_dataset_covid19\\test", transform=transform)
test_dataset = torchvision.datasets.ImageFolder(root="C:\\Users\\user\\Desktop\\xray_dataset_covid19\\train", transform=transform)

# Define data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# set seed and random value
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
#defining model

class PneumoniaClassifier(nn.Module):
    def __init__(self):
        super(PneumoniaClassifier, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 54 * 54, 128) 
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 54 * 54)  
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    
#specify loss function and optimizer
model = PneumoniaClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

#define metrics to track performance during training
epochs = 10
train_losses = []
test_losses = []
accuracy_list = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #defining model
# ----> 3 class PneumoniaClassifier(nn.Module):
#       4     def __init__(self):
#       5         super(PneumoniaClassifier, self).__init__()
#
# NameError: name 'nn' is not defined

# %%
#training the model for data
for epoch in range(epochs):
    running_loss = 0
    correct = 0
    total = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()
    
    train_loss = running_loss / len(train_loader)
    train_losses.append(train_loss)
    
    # Evaluate on test set
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
    test_loss /= len(test_loader)
    test_losses.append(test_loss)
    
    accuracy = 100 * correct / total
    accuracy_list.append(accuracy)
    
    print(f'Epoch [{epoch+1}/{epochs}], '
          f'Train Loss: {train_loss:.4f}, '
          f'Test Loss: {test_loss:.4f}, '
          f'Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/10], Train Loss: 0.4105, Test Loss: 4.5534, Accuracy: 50.00%
# Epoch [2/10], Train Loss: 0.7909, Test Loss: 1.9938, Accuracy: 77.03%
# Epoch [3/10], Train Loss: 0.0493, Test Loss: 3.0533, Accuracy: 77.70%
# Epoch [4/10], Train Loss: 0.0195, Test Loss: 1.9876, Accuracy: 85.81%
# Epoch [5/10], Train Loss: 0.0000, Test Loss: 1.8545, Accuracy: 87.16%
# Epoch [6/10], Train Loss: 0.1229, Test Loss: 2.2793, Accuracy: 87.16%
# Epoch [7/10], Train Loss: 0.0000, Test Loss: 5.4642, Accuracy: 79.73%
# Epoch [8/10], Train Loss: 0.2275, Test Loss: 5.8402, Accuracy: 79.73%
# Epoch [9/10], Train Loss: 0.0000, Test Loss: 4.0358, Accuracy: 83.78%
# Epoch [10/10], Train Loss: 0.0000, Test Loss: 3.2617, Accuracy: 85.81%

# %%
#PLotting loss function

plt.figure(figsize=(10, 5))
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()
plt.title('Loss Curve')
plt.show()

# %%
#Plotting Accuracy

plt.figure(figsize=(10, 5))
plt.plot(accuracy_list, label='Accuracy', color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Curve')
#plt.legend()
plt.show()

# %%
##VISUALISING THE PREDICTIONS
import matplotlib.pyplot as plt
import numpy as np

# Get a batch of test images
images, labels = next(iter(test_loader))

# Make predictions
outputs = model(images)
_, predicted = torch.max(outputs, 1)

# Plot images with predicted labels
fig, axes = plt.subplots(4, 4, figsize=(12, 12))
for i, ax in enumerate(axes.flat):
    ax.imshow(np.transpose(images[i], (1, 2, 0)))
    ax.set_title(f'Predicted: {"PNEUMONIA" if predicted[i] == 1 else "NORMAL"}\nActual: {"PNEUMONIA" if labels[i] == 1 else "NORMAL"}')
    ax.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
